# %% [markdown]
# Xây dựng bộ phát hiện đối tượng với thuật toán YOLOv3 được viết bằng thư viện Keras. Thư viện này bao gồm đầy đủ các module: phát hiện đối tượng với pre-trainded model, huấn luyện lại mô hình, phát hiện đối tượng ảnh trên ảnh/video/webcam.
#
# Đầu tiên, ta sẽ khởi tạo Google Colab với sử dụng 1 GPU. Sau đó thực hiện kết nối với Google Drive của tài khoản cá nhân như sau:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
lab_path = "/content/gdrive/My\ Drive/AdvancedComputerVision/keras-yolo3"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Sau đó, sử dụng git để clone thư mục project từ github của tác giả experiencor với đường dẫn như sau. Lưu ý rằng, ta nên đặt thực project kế bên file jupyter notebook này để tiện thao tác.

# %%
# !git clone https://github.com/experiencor/keras-yolo3.git $lab_path

# %% [markdown]
# Sau đó tiến hành cài đặt các thư viện cần thiết để có thể sử dụng được keras-yolo3. Đây là bước thực hiện quan trọng vì thông thường các thư viện sẽ sử dụng các thư viện bên thứ 3 với các phiên bản cố định. Do đó, để đảm bảo thư viện keras-yolo3 sử dụng trơn tru thì ta sẽ cài đặt các thư viện kèm theo trong file requirements.txt.

# %%
# !pip install -r $lab_path/requirements.txt
# Out:
# Requirement already satisfied: absl-py==0.9.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: astor==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 2)) (0.8.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting google-pasta==0.1.8
#   Downloading https://files.pythonhosted.org/packages/c3/fd/1e86bc4837cc9a3a5faf3db9b1854aa04ad35b5f381f9648fbe81a6f94e4/google_pasta-0.1.8-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 3.1MB/s
# Collecting grpcio==1.26.0
#   Downloading https://files.pythonhosted.org/packages/17/8f/f79c5c174bebece41f824dd7b1ba98da45dc2d4c373b38ac6a7f6a5acb5e/grpcio-1.26.0-cp36-cp36m-manylinux2010_x86_64.whl (2.4MB)
#      |████████████████████████████████| 2.4MB 10.3MB/s
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: Keras==2.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 7)) (2.3.1)
# Requirement already satisfied: Keras-Applications==1.0.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 8)) (1.0.8)
# Collecting Keras-Preprocessing==1.1.0
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 6.4MB/s
# Collecting Markdown==3.1.1
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 9.2MB/s
# Collecting numpy==1.18.1
#   Downloading https://files.pythonhosted.org/packages/62/20/4d43e141b5bc426ba38274933ef8e76e85c7adea2c321ecf9ebf7421cedf/numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl (20.1MB)
#      |████████████████████████████████| 20.2MB 1.5MB/s
# Requirement already satisfied: opencv-contrib-python==4.1.2.30 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 12)) (4.1.2.30)
# Collecting opt-einsum==3.1.0
#   Downloading https://files.pythonhosted.org/packages/b8/83/755bd5324777875e9dff19c2e59daec837d0378c09196634524a3d7269ac/opt_einsum-3.1.0.tar.gz (69kB)
#      |████████████████████████████████| 71kB 8.0MB/s
# Collecting protobuf==3.11.2
#   Downloading https://files.pythonhosted.org/packages/ca/ac/838c8c8a5f33a58132dd2ad2a30329f6ae1614a9f56ffb79eaaf71a9d156/protobuf-3.11.2-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 35.2MB/s
# Collecting PyYAML==5.3
#   Downloading https://files.pythonhosted.org/packages/3d/d9/ea9816aea31beeadccd03f1f8b625ecf8f645bd66744484d162d84803ce5/PyYAML-5.3.tar.gz (268kB)
#      |████████████████████████████████| 276kB 39.3MB/s
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 16)) (1.4.1)
# Collecting six==1.14.0
#   Downloading https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting tensorboard==1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 37.5MB/s
# Collecting tensorflow==1.15.0
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 40kB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 31.2MB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 21)) (1.1.0)
# Requirement already satisfied: tqdm==4.41.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 22)) (4.41.1)
# Collecting Werkzeug==0.16.0
#   Downloading https://files.pythonhosted.org/packages/ce/42/3aeda98f96e85fd26180534d36570e4d18108d62ae36f87694b476b83d6f/Werkzeug-0.16.0-py2.py3-none-any.whl (327kB)
#      |████████████████████████████████| 327kB 36.8MB/s
# Collecting wrapt==1.11.2
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Requirement already satisfied: setuptools>=36 in /usr/local/lib/python3.6/dist-packages (from Markdown==3.1.1->-r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 10)) (49.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.15.0->-r /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/requirements.txt (line 18)) (0.34.2)
# Building wheels for collected packages: gast, opt-einsum, PyYAML, wrapt
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=c6470fc9a1d9c01b47c9f2da778d7c84df7282891fdc09466c184fde137c7c21
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for opt-einsum (setup.py) ... done
#   Created wheel for opt-einsum: filename=opt_einsum-3.1.0-cp36-none-any.whl size=61682 sha256=0fe3a75cdcc2995675a395a73aef0203fbf99a86b6c65094eb489734c17cc7b3
#   Stored in directory: /root/.cache/pip/wheels/2c/b1/94/43d03e130b929aae7ba3f8d15cbd7bc0d1cb5bb38a5c721833
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3-cp36-cp36m-linux_x86_64.whl size=44229 sha256=120b11feab24d5d01cb9adf3b6ba8615fd165469d481e84a4bf664ea5a6949c1
#   Stored in directory: /root/.cache/pip/wheels/e4/76/4d/a95b8dd7b452b69e8ed4f68b69e1b55e12c9c9624dd962b191
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp36-cp36m-linux_x86_64.whl size=67534 sha256=e9693e64f6ef5e769755a933b55ab584aa8b263434b7bc31115a7987ef57a72e
#   Stored in directory: /root/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
# Successfully built gast opt-einsum PyYAML wrapt
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement six~=1.12.0, but you'll have six 1.14.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: gast, six, google-pasta, grpcio, numpy, Keras-Preprocessing, Markdown, opt-einsum, protobuf, PyYAML, Werkzeug, tensorboard, wrapt, tensorflow-estimator, tensorflow
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#   Found existing installation: grpcio 1.30.0
#     Uninstalling grpcio-1.30.0:
#       Successfully uninstalled grpcio-1.30.0
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Found existing installation: Markdown 3.2.2
#     Uninstalling Markdown-3.2.2:
#       Successfully uninstalled Markdown-3.2.2
#   Found existing installation: opt-einsum 3.2.1
#     Uninstalling opt-einsum-3.2.1:
#       Successfully uninstalled opt-einsum-3.2.1
#   Found existing installation: protobuf 3.12.2
#     Uninstalling protobuf-3.12.2:
#       Successfully uninstalled protobuf-3.12.2
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: wrapt 1.12.1
#     Uninstalling wrapt-1.12.1:
#       Successfully uninstalled wrapt-1.12.1
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# Successfully installed Keras-Preprocessing-1.1.0 Markdown-3.1.1 PyYAML-5.3 Werkzeug-0.16.0 gast-0.2.2 google-pasta-0.1.8 grpcio-1.26.0 numpy-1.18.1 opt-einsum-3.1.0 protobuf-3.11.2 six-1.14.0 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1 wrapt-1.11.2

# %% [markdown]
# 1. Thử nghiệm với pretrained model của tác giả thuật toán YOLO.
#
# File mô hình huấn luyện sẵn được đặt ở đường dẫn sau https://pjreddie.com/media/files/yolov3.weights
# Lưu ý là file mô hình cần được đặt trong thư mục gốc của thư viện để tiện cho việc thực hiện.

# %%
#!wget https://pjreddie.com/media/files/yolov3.weights -O $lab_path/yolov3.weights

# %% [markdown]
# Sau đó, ta tiến hành sử dụng pretrained model để phát hiện đối tượng trong ảnh cho trước. Sử dụng chương trình yolo3_one_file_to_detect_them_all.py với file mô hình đã download ở file trước đó để phát hiện các đối tượng trong ảnh. Tập dữ liệu các đối tượng phát hiện được lấy từ tập PASCAL VOC 2012.
#
# Ảnh kết quả phát hiện đối tượng trên pretrained model cho tập dữ liệu này được minh hoạ như ở hình sau:
#
# ![alt text](https://i.imgur.com/6nun5fl.jpg)

# %%
# !python $lab_path/yolo3_one_file_to_detect_them_all.py -w $lab_path/yolov3.weights -i $lab_path/dogs_1280p_0.jpg
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-07-22 05:07:19.906059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-22 05:07:19.965122: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-22 05:07:19.965212: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (5f87b8929146): /proc/driver/nvidia/version does not exist
# 2020-07-22 05:07:19.965791: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-07-22 05:07:19.973417: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-07-22 05:07:19.973742: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x20e0bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-22 05:07:19.973792: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# loading weights of convolution #0
# loading weights of convolution #1
# loading weights of convolution #2
# loading weights of convolution #3
# no convolution #4
# loading weights of convolution #5
# loading weights of convolution #6
# loading weights of convolution #7
# no convolution #8
# loading weights of convolution #9
# loading weights of convolution #10
# no convolution #11
# loading weights of convolution #12
# loading weights of convolution #13
# loading weights of convolution #14
# no convolution #15
# loading weights of convolution #16
# loading weights of convolution #17
# no convolution #18
# loading weights of convolution #19
# loading weights of convolution #20
# no convolution #21
# loading weights of convolution #22
# loading weights of convolution #23
# no convolution #24
# loading weights of convolution #25
# loading weights of convolution #26
# no convolution #27
# loading weights of convolution #28
# loading weights of convolution #29
# no convolution #30
# loading weights of convolution #31
# loading weights of convolution #32
# no convolution #33
# loading weights of convolution #34
# loading weights of convolution #35
# no convolution #36
# loading weights of convolution #37
# loading weights of convolution #38
# loading weights of convolution #39
# no convolution #40
# loading weights of convolution #41
# loading weights of convolution #42
# no convolution #43
# loading weights of convolution #44
# loading weights of convolution #45
# no convolution #46
# loading weights of convolution #47
# loading weights of convolution #48
# no convolution #49
# loading weights of convolution #50
# loading weights of convolution #51
# no convolution #52
# loading weights of convolution #53
# loading weights of convolution #54
# no convolution #55
# loading weights of convolution #56
# loading weights of convolution #57
# no convolution #58
# loading weights of convolution #59
# loading weights of convolution #60
# no convolution #61
# loading weights of convolution #62
# loading weights of convolution #63
# loading weights of convolution #64
# no convolution #65
# loading weights of convolution #66
# loading weights of convolution #67
# no convolution #68
# loading weights of convolution #69
# loading weights of convolution #70
# no convolution #71
# loading weights of convolution #72
# loading weights of convolution #73
# no convolution #74
# loading weights of convolution #75
# loading weights of convolution #76
# loading weights of convolution #77
# loading weights of convolution #78
# loading weights of convolution #79
# loading weights of convolution #80
# loading weights of convolution #81
# no convolution #82
# no convolution #83
# loading weights of convolution #84
# no convolution #85
# no convolution #86
# loading weights of convolution #87
# loading weights of convolution #88
# loading weights of convolution #89
# loading weights of convolution #90
# loading weights of convolution #91
# loading weights of convolution #92
# loading weights of convolution #93
# no convolution #94
# no convolution #95
# loading weights of convolution #96
# no convolution #97
# no convolution #98
# loading weights of convolution #99
# loading weights of convolution #100
# loading weights of convolution #101
# loading weights of convolution #102
# loading weights of convolution #103
# loading weights of convolution #104
# loading weights of convolution #105
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# dog: 84.21645760536194%
# dog: 98.64489436149597%

# %% [markdown]
# 2. Huấn luyện dữ liệu với keras-yolo3
#
# ![alt text](https://i.imgur.com/45SRniL.jpg)
#
# Bước tiếp theo, ta sẽ tiến hành huấn luyện trên tập dữ liệu mới là gấu mèo (raccoon). Tập dữ liệu này được tải từ https://github.com/experiencor/raccoon_dataset.git
#
# Lưu ý rằng, ta sẽ chỉ sử dụng 2 thư mục của github này là images và annotations. Trong đó,
#
# *   images: thư mục chứa các ảnh về gấu mèo
# *   annotations: tương ứng với từng file ảnh của thư mục images, ta có một file .xml chứa thông tin về vị trí chính xác của đối tượng (gấu mèo) trong ảnh.
#
# Các bạn nên xem kỹ định dạng của các file XML này để biết cấu trúc file gán nhãn phục vụ cho việc thực hiện đồ án sau này.

# %%
# !git clone https://github.com/experiencor/raccoon_dataset.git $lab_path/raccoon_dataset

# %% [markdown]
# Một file khác cũng rất quan trọng của các mô hình huấn luyện học sâu nói chung và YOLO nói riêng là file cấu hình (config) các tham số khi huấn luyện.
#
# Trong thư viện này, file config được đặt trong thư mục /zoo. Ví dụ như config_raccoon.json. Các tham số cơ bản của file config như:
# - Đường dẫn đến thư mục train, validation (mặc định chia tỉ lệ train:validation = 8:2 nếu không có tham số gắn sẵn)
# - GPU sử dụng để huấn luyện
# - File pretrained cho tập image net backend.h5
# - Learning rate
# - Batch size
#
# Sau khi đã cấu hình file config, ta sẽ tiến hành huấn luyện:

# %% [markdown]
# Để chương trình train có thể chạy được ta phải tải thêm file backend.h5 chứa pretrained model của backbone model và đặt ở thư mục lab_path:
# https://drive.google.com/file/d/1f3Ylajkfg69iXc5159oJlYsq-9D_Px50/view?usp=sharing

# %%
# !python $lab_path/train.py -c $lab_path/zoo/config_vehicle.json
# Out:
# Using TensorFlow backend.
# 2020-07-22 05:52:37.749748: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-07-22 05:52:37.755581: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-07-22 05:52:37.755938: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x158ebc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-22 05:52:37.755978: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-22 05:52:37.760480: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-22 05:52:37.901551: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 05:52:37.902536: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x158ed80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-07-22 05:52:37.902571: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-07-22 05:52:37.903961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 05:52:37.904697: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-07-22 05:52:37.925490: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-07-22 05:52:38.216720: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-07-22 05:52:38.334797: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-07-22 05:52:38.386204: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-07-22 05:52:38.702770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-07-22 05:52:38.881749: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-07-22 05:52:39.546123: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-22 05:52:39.546429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 05:52:39.547367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 05:52:39.548098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-07-22 05:52:39.548294: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-07-22 05:52:39.549965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-07-22 05:52:39.550005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-07-22 05:52:39.550026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-07-22 05:52:39.550312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 05:52:39.551190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 05:52:39.551970: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10297 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/train.py:26: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# valid_annot_folder not exists. Spliting the trainining set.
# Seen labels: 	{'motorcycle': 3374, 'car': 1077, 'bus': 59}
#
# Given labels: 	['bus', 'car', 'motorcycle']
#
# Training on: 	['bus', 'car', 'motorcycle']
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/yolo.py:26: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/yolo.py:151: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# resizing:  416 416
# Epoch 1/103
# 2020-07-22 05:53:52.589029: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-22 05:53:56.719569: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# WARNING:tensorflow:From /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/callbacks.py:19: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
#  - 161s - loss: 340.1374 - yolo_layer_1_loss: 36.0291 - yolo_layer_2_loss: 88.1109 - yolo_layer_3_loss: 215.9974
#
# Epoch 00001: loss improved from inf to 340.13738, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 2/103
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
#  - 107s - loss: 77.5559 - yolo_layer_1_loss: 8.5062 - yolo_layer_2_loss: 17.4650 - yolo_layer_3_loss: 51.5847
#
# Epoch 00002: loss improved from 340.13738 to 77.55586, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 3/103
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
#  - 108s - loss: 59.2364 - yolo_layer_1_loss: 6.6881 - yolo_layer_2_loss: 13.8606 - yolo_layer_3_loss: 38.6877
#
# Epoch 00003: loss improved from 77.55586 to 59.23638, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# resizing:  384 384
# Epoch 4/103
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
#  - 99s - loss: 30.4774 - yolo_layer_1_loss: 1.4894 - yolo_layer_2_loss: 5.9760 - yolo_layer_3_loss: 23.0121
#
# Epoch 00004: loss improved from 59.23638 to 30.47740, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 5/103
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
#  - 102s - loss: 24.2877 - yolo_layer_1_loss: 1.1913 - yolo_layer_2_loss: 4.1858 - yolo_layer_3_loss: 18.9106
#
# Epoch 00005: loss improved from 30.47740 to 24.28766, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 6/103
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
#  - 110s - loss: 23.3319 - yolo_layer_1_loss: 1.4020 - yolo_layer_2_loss: 4.5359 - yolo_layer_3_loss: 17.3940
#
# Epoch 00006: loss improved from 24.28766 to 23.33190, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# resizing:  416 416
# Epoch 7/103
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
#  - 97s - loss: 20.8433 - yolo_layer_1_loss: 0.6966 - yolo_layer_2_loss: 3.6245 - yolo_layer_3_loss: 16.5222
#
# Epoch 00007: loss improved from 23.33190 to 20.84326, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 8/103
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
#  - 109s - loss: 21.1176 - yolo_layer_1_loss: 0.9402 - yolo_layer_2_loss: 4.0992 - yolo_layer_3_loss: 16.0782
#
# Epoch 00008: loss did not improve from 20.84326
# Epoch 9/103
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
#  - 95s - loss: 19.4439 - yolo_layer_1_loss: 0.7043 - yolo_layer_2_loss: 3.2919 - yolo_layer_3_loss: 15.4477
#
# Epoch 00009: loss improved from 20.84326 to 19.44390, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 10/103
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
#  - 104s - loss: 19.5880 - yolo_layer_1_loss: 0.6609 - yolo_layer_2_loss: 3.3912 - yolo_layer_3_loss: 15.5359
#
# Epoch 00010: loss did not improve from 19.44390
# Epoch 11/103
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
#  - 111s - loss: 20.0502 - yolo_layer_1_loss: 0.9689 - yolo_layer_2_loss: 3.7712 - yolo_layer_3_loss: 15.3100
#
# Epoch 00011: loss did not improve from 19.44390
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 12/103
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
#  - 105s - loss: 18.2248 - yolo_layer_1_loss: 0.5105 - yolo_layer_2_loss: 3.0228 - yolo_layer_3_loss: 14.6915
#
# Epoch 00012: loss improved from 19.44390 to 18.22479, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 13/103
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
#  - 98s - loss: 16.9927 - yolo_layer_1_loss: 0.3613 - yolo_layer_2_loss: 2.3788 - yolo_layer_3_loss: 14.2525
#
# Epoch 00013: loss improved from 18.22479 to 16.99269, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 14/103
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
#  - 111s - loss: 17.9137 - yolo_layer_1_loss: 0.6042 - yolo_layer_2_loss: 2.9842 - yolo_layer_3_loss: 14.3254
#
# Epoch 00014: loss did not improve from 16.99269
# Epoch 15/103
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
#  - 106s - loss: 17.2692 - yolo_layer_1_loss: 0.3967 - yolo_layer_2_loss: 2.8762 - yolo_layer_3_loss: 13.9964
#
# Epoch 00015: loss did not improve from 16.99269
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 16/103
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
#  - 117s - loss: 18.2506 - yolo_layer_1_loss: 0.6509 - yolo_layer_2_loss: 3.4271 - yolo_layer_3_loss: 14.1726
#
# Epoch 00016: loss did not improve from 16.99269
# Epoch 17/103
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
#  - 108s - loss: 16.9921 - yolo_layer_1_loss: 0.4275 - yolo_layer_2_loss: 2.6137 - yolo_layer_3_loss: 13.9509
#
# Epoch 00017: loss improved from 16.99269 to 16.99212, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 18/103
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
#  - 97s - loss: 16.5607 - yolo_layer_1_loss: 0.2625 - yolo_layer_2_loss: 2.4144 - yolo_layer_3_loss: 13.8838
#
# Epoch 00018: loss improved from 16.99212 to 16.56073, saving model to /content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/vehicle.h5
# Epoch 19/103
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
#  - 108s - loss: 17.8437 - yolo_layer_1_loss: 0.5354 - yolo_layer_2_loss: 3.0826 - yolo_layer_3_loss: 14.2257
#
# Epoch 00019: loss did not improve from 16.56073
# Epoch 20/103
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
#  - 104s - loss: 17.3629 - yolo_layer_1_loss: 0.5062 - yolo_layer_2_loss: 2.6003 - yolo_layer_3_loss: 14.2564
#
# Epoch 00020: loss did not improve from 16.56073
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 21/103
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
#  - 107s - loss: 17.4051 - yolo_layer_1_loss: 0.5544 - yolo_layer_2_loss: 2.8839 - yolo_layer_3_loss: 13.9667
#
# Epoch 00021: loss did not improve from 16.56073
# Epoch 22/103
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
#  - 113s - loss: 18.3597 - yolo_layer_1_loss: 0.7917 - yolo_layer_2_loss: 3.3246 - yolo_layer_3_loss: 14.2434
#
# Epoch 00022: loss did not improve from 16.56073
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Epoch 23/103
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
#  - 110s - loss: 17.6801 - yolo_layer_1_loss: 0.5318 - yolo_layer_2_loss: 3.1634 - yolo_layer_3_loss: 13.9849
#
# Epoch 00023: loss did not improve from 16.56073
# Epoch 24/103
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
#  - 118s - loss: 17.9149 - yolo_layer_1_loss: 0.6373 - yolo_layer_2_loss: 3.1569 - yolo_layer_3_loss: 14.1207
#
# Epoch 00024: loss did not improve from 16.56073
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# Epoch 25/103
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
#  - 108s - loss: 17.7274 - yolo_layer_1_loss: 0.5969 - yolo_layer_2_loss: 2.9315 - yolo_layer_3_loss: 14.1990
#
# Epoch 00025: loss did not improve from 16.56073
# Epoch 00025: early stopping
# bus: 0.3448
# car: 0.8867
# motorcycle: 0.6294
# mAP: 0.6203
# save weight

# %% [markdown]
# Sau khi quá trình huấn luyện kết thúc, hệ thống sẽ lưu mô hình raccoon.h5 trong thư mục của máy ảo colab. Ta có thể sửa lại mã nguồn của thư viện để các file mô hình và file trung gian đặt trong thư mục của thư viện cho gọn gàng.
#
# Sau đó, ta sẽ tiến hành thử nghiệm mô hình đã huấn luyện trên ảnh mẫu lấy từ mạng internet hoặc thư mục ảnh validation/train.

# %%
# !python $lab_path/predict.py -c $lab_path/zoo/config_vehicle.json -i $lab_path/vehicle_dataset/007.asf -o $lab_path
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-07-22 06:48:39.965053: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-22 06:48:39.987531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:39.988326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-07-22 06:48:39.988635: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-07-22 06:48:39.990255: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-07-22 06:48:39.991523: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-07-22 06:48:39.991945: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-07-22 06:48:39.993736: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-07-22 06:48:39.995058: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-07-22 06:48:39.999220: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-22 06:48:39.999377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.000211: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.000954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-07-22 06:48:40.001408: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-07-22 06:48:40.006874: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-07-22 06:48:40.007118: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2050d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-22 06:48:40.007157: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-22 06:48:40.060046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.060944: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2050f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-07-22 06:48:40.060981: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-07-22 06:48:40.061185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.061936: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-07-22 06:48:40.062027: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-07-22 06:48:40.062081: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-07-22 06:48:40.062139: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-07-22 06:48:40.062193: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-07-22 06:48:40.062243: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-07-22 06:48:40.062294: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-07-22 06:48:40.062355: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-22 06:48:40.062490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.063315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.064053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-07-22 06:48:40.064143: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-07-22 06:48:40.065591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-07-22 06:48:40.065630: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-07-22 06:48:40.065654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-07-22 06:48:40.065860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.066656: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-22 06:48:40.067404: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-07-22 06:48:40.067461: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
#   0% 0/1830112 [00:00<?, ?it/s]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2020-07-22 06:48:54.744538: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-22 06:48:55.505628: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
#   1% 13726/1830112 [33:10<68:46:42,  7.34it/s]Traceback (most recent call last):
#   File "/content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/predict.py", line 132, in <module>
#     _main_(args)
#   File "/content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/predict.py", line 83, in _main_
#     batch_boxes = get_yolo_boxes(infer_model, images, net_h, net_w, config['model']['anchors'], obj_thresh, nms_thresh)
#   File "/content/gdrive/My Drive/AdvancedComputerVision/keras-yolo3/utils/utils.py", line 234, in get_yolo_boxes
#     image_h, image_w, _ = images[0].shape
# AttributeError: 'NoneType' object has no attribute 'shape'
#   1% 13726/1830112 [33:10<73:09:14,  6.90it/s]

# %% [markdown]
# Như vậy, trong phần bài tập này chúng ta đã làm quen với thư viện keras-yolo3. Trong phần đồ án giữa kỳ, ta sẽ tiến hành trên dữ liệu video giao thông được thu tại TP. Hồ Chí Minh. Ví dụ, ảnh sau được cắt tại góc đường Nam Kỳ Khởi Nghĩa - Võ Thị Sáu.
#
# ![alt text](https://i.imgur.com/NQBeNpG.jpg)
#
# Mục tiêu của đồ án này là sử dụng thuật toán YOLOv3 để tiến hành ước lượng lưu lượng giao thông theo các hướng đi.
#
# Đầu tiên, ta sẽ thử sử dụng pretrained model lên dữ liệu video thực tế.
#
# Sau đó tiến hành xây dựng bộ dữ liệu gán nhãn cho ngữ cảnh camera giao thông.
#
# Huấn luyện lại mô hình với dữ liệu gán nhãn mới.
#
# Phát hiện và đếm các đối tượng xe máy, xe hơi trong video giao thông.
#
# Video test: https://drive.google.com/file/d/1u__2tl79nSevF_pnvwsVd79Hu1aWLJQE/view?usp=sharing
#
# Tập ảnh dùng để train: https://drive.google.com/file/d/1mKBQerK3F8UKuyoOugd_roCnDfvswXtn/view?usp=sharing
